# %%
from astropy.io import fits

# Read the hogg2018.fits file into a variable
filename = "hogg2018.fits"
with fits.open(filename) as hdul:
    data = hdul[1].data  # assuming the main table is in the first extension

# Now `data` is a numpy record array with the FITS table contents
